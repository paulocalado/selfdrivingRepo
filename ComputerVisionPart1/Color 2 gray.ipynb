# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
image_color = mpimg.imread('image_lane_c.jpg')

# %%
plt.imshow(image_color)

# %%
image_color.shape
#540 pixels of heigth, 960 pixels of width and 3 layers (RGB image)
# Out:
# (540, 960, 3)

# %%
image_gray = cv2.cvtColor(image_color,cv2.COLOR_RGB2GRAY)
plt.imshow(image_gray)

# %%
plt.imshow(image_gray,cmap='gray')

# %%
image_gray.shape
#as we can see, now we only have 1 color channel
# Out:
# (540, 960)

# %%
image_gray[image_gray<50] = 150

# %%
plt.imshow(image_gray,cmap='gray')

# %%
image_color
# Out:
# array([[[122, 185, 229],
#         [122, 185, 229],
#         [123, 186, 230],
#         ...,
#         [123, 184, 229],
#         [123, 184, 229],
#         [123, 184, 229]],
#
#        [[122, 185, 229],
#         [122, 185, 229],
#         [122, 185, 229],
#         ...,
#         [123, 184, 229],
#         [123, 184, 229],
#         [123, 184, 229]],
#
#        [[122, 185, 229],
#         [122, 185, 229],
#         [122, 185, 229],
#         ...,
#         [123, 184, 229],
#         [123, 184, 229],
#         [123, 184, 229]],
#
#        ...,
#
#        [[154, 166, 154],
#         [156, 168, 156],
#         [153, 165, 153],
#         ...,
#         [180, 197, 181],
#         [181, 198, 182],
#         [181, 198, 182]],
#
#        [[162, 174, 164],
#         [160, 172, 162],
#         [152, 164, 154],
#         ...,
#         [174, 192, 176],
#         [175, 193, 177],
#         [176, 194, 178]],
#
#        [[156, 168, 158],
#         [148, 160, 150],
#         [137, 149, 139],
# ...

# %%
cv2.imwrite('lane_to_gray.jpg',image_gray)
# Out:
# True
